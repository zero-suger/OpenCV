# %% [markdown]
# # **Flipping the IMAGE**

# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow

img = cv.imread('/content/cat.jpeg')

resize_img = cv.resize(img, (500,500))

flip_img = cv.flip(resize_img, 0) # 0 flipping the image vertically
cv2_imshow(flip_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F54B4017490>

# %%
flip_img = cv.flip(resize_img, 1) # flipping the image horizontally
cv2_imshow(flip_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F54B4015C00>

# %%
flip_img = cv.flip(resize_img, -1) # flipping the image horizontally and vertically
cv2_imshow(flip_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F54B4016EC0>

# %% [markdown]
# # **Transform IMAGE**

# %%
# assert img is not None, "file could not be read, check with os.path.exists()"
# rows,cols = img.shape
# M = np.float32([[1,0,100],[0,1,50]])
# dst = cv.warpAffine(resize_img,M,(cols,rows))
# cv2_imshow(dst)
# cv.waitKey(0)
# cv.destroyAllWindows()
