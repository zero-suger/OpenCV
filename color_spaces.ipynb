# %% [markdown]
# **OpenCV**: use **BGR color** representation but, **matplotlib** uses **RGB**.

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/horse.jpeg')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7F344A3DA050>

# %%
# BGR to Grayscale

img_grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(img_grayscale)
# Out:
# <PIL.Image.Image image mode=L size=509x339 at 0x7F344A293520>

# %%
# BGR to HSV

img_HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

cv2_imshow(img_HSV)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7F344A290880>

# %%
# BGR to L * A * B

img_LAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

cv2_imshow(img_LAB)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7F344A292AD0>

# %%
# BGR to RGB

img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

cv2_imshow(img_RGB)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7F344A2936D0>
